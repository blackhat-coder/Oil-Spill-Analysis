# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('Oil_Spill_Sab_Data_Niger_Delta-_2010-2020.csv')

# %%
data.shape
# Out:
# (6798, 17)

# %%
data.head()
# Out:
#    ID Company Incident_date Days_of_the_Wk Months_of_the_Yr  Years  \
# 0   1    SPDC    2010-01-03            Sun              Jan   2010
# 1   2    SPDC    2010-01-03            Sun              Jan   2010
# 2   3    NAOC    2010-01-05            Tue              Jan   2010
# 3   4    SPDC    2010-01-05            Tue              Jan   2010
# 4   5    NAOC    2010-01-06            Wed              Jan   2010
#
#   Contaminant Type_of_fa Cause  \
# 0          cr              sab
# 1          cr              sab
# 2          cr              sab
# 3          cr              sab
# 4          cr              sab
#
#                                         Site_locat  Latitude  Longitude  \
# 0                      12" IMR-EBUBU T/L AT KOMKOM  4.878083   7.172556
# 1                        8" ISIMIRI D/L AT ISIMIRI  4.878194   7.230583
# 2                         24" OGODA/BRASS P/L ODAU  4.833556   6.498889
# 3                                       Kokori d\L  5.597444   6.068583
# 4  18" TEBIDABA/BRASS P/L AT OGONIGBENE 1 M8 RISER  4.474889   6.127833
#
#              LGA States_affected Spill_area  MoY  DoW
# 0         Oyigbo              RI         la    1    1
# 1      Ukwa West              AB         sw    1    1
# 2     Abua-Odual              RI         la    1    3
# 3  Ughelli-North              DE         la    1    3
# 4          Brass              BY         sw    1    4

# %%
data.tail()
# Out:
#         ID Company Incident_date Days_of_the_Wk Months_of_the_Yr  Years  \
# 6793  6794    SPDC    2020-12-26            Sat              Dec   2020
# 6794  6795    SPDC    2020-12-29            Tue              Dec   2020
# 6795  6796    SPDC    2020-12-29            Tue              Dec   2020
# 6796  6797    SPDC    2020-12-29            Tue              Dec   2020
# 6797  6798    SPDC    2020-12-30            Wed              Dec   2020
#
#      Contaminant Type_of_fa Cause  \
# 6793                     pl   sab
# 6794          cr         pl   sab
# 6795          cr         pl   sab
# 6796          cr         pl   sab
# 6797          no         pl   sab
#
#                                              Site_locat  Latitude  Longitude  \
# 6793                  12"Oguta-Egbema pipeline@ Eziorsu  5.617620   6.758370
# 6794  18" Assa-Rumuekpe P/L ROW @ Ohaji-Egbema in Im...  5.288020   6.781340
# 6795  18" Assa-Rumuekpe P/L Ochia @ Ohaji/Egbema in ...  5.345820   6.794620
# 6796          14" Okordia-Rumuekpe Trunk Line @ Akinima  5.129826   6.473528
# 6797                                 20'' TEP @ OTUMARA  5.646222   5.147253
#
#                    LGA States_affected Spill_area  MoY  DoW
# 6793      Ohaji/Egbema              IM         la   12    7
# 6794      Ohaji/Egbema              IM         la   12    3
# 6795      Ohaji/Egbema              IM         la   12    3
# 6796           Yenagoa              BY         ss   12    3
# 6797  Warri-South-West              DE         sw   12    4

# %%
data.columns
# Out:
# Index(['ID', 'Company', 'Incident_date', 'Days_of_the_Wk', 'Months_of_the_Yr',
#        'Years', 'Contaminant', 'Type_of_fa', 'Cause', 'Site_locat', 'Latitude',
#        'Longitude', 'LGA', 'States_affected', 'Spill_area', 'MoY', 'DoW'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6798 entries, 0 to 6797
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                6798 non-null   int64
#  1   Company           6798 non-null   object
#  2   Incident_date     6798 non-null   object
#  3   Days_of_the_Wk    6798 non-null   object
#  4   Months_of_the_Yr  6798 non-null   object
#  5   Years             6798 non-null   int64
#  6   Contaminant       6798 non-null   object
#  7   Type_of_fa        6798 non-null   object
#  8   Cause             6798 non-null   object
#  9   Site_locat        6798 non-null   object
#  10  Latitude          6798 non-null   float64
#  11  Longitude         6798 non-null   float64
#  12  LGA               6798 non-null   object
#  13  States_affected   6798 non-null   object
#  14  Spill_area        6798 non-null   object
#  15  MoY               6798 non-null   int64
#  16  DoW               6798 non-null   int64
# dtypes: float64(2), int64(4), object(11)
# memory usage: 903.0+ KB

# %% [markdown]
# ## Our target would be the LGA

# %%
for i in data.columns:
    if data[i].dtype == 'object':
        print(f"       COLUMN:   {i}")  
        
        print("==================================")
        print(" ")
        print(data[i].value_counts())

        print(" ")
        print("___________________________________")
# Out:
#        COLUMN:   Company
# ==================================
#
# NAOC                          4026
# SPDC                          1912
# NPDC                           197
# PPMC                           129
# CHEVRON                        115
# EROTON E&P                      78
# HERITAGE                        66
# TOTAL                           46
# SEPLAT                          35
# FIRST                           34
# NDWEST                          32
# AITEO E&P                       29
# ADDAX                           19
# ERL                             17
# MIDWESTERN                      17
# POOCN                           16
# NDPR                             8
# PLATFORM PETROLEUM LIMITED       6
# PLATFORM                         6
# SEEPCO                           3
# NECONDE                          2
# MILLENNIUM O&G                   2
# MPN                              1
# SAHARA                           1
# NEWCROSS E&P                     1
# Name: Company, dtype: int64
#
# ___________________________________
#        COLUMN:   Incident_date
# ==================================
#
# 2013-03-22    39
# 2019-01-16    20
# 2015-05-20    16
# 2011-10-31    16
# 2011-02-09    13
#               ..
# 2017-07-10     1
# 2018-11-29     1
# 2019-06-13     1
# 2017-02-04     1
# 2010-03-18     1
# Name: Incident_date, Length: 2706, dtype: int64
#
# ___________________________________
#        COLUMN:   Days_of_the_Wk
# ==================================
#
# Wed    1091
# Tue    1005
# Mon    1005
# Fri    1003
# Thu     963
# Sun     880
# Sat     851
# Name: Days_of_the_Wk, dtype: int64
#
# ___________________________________
#        COLUMN:   Months_of_the_Yr
# ==================================
#
# May    732
# Jan    613
# Aug    607
# Nov    606
# Jul    580
# Mar    566
# Jun    565
# Feb    523
# Dec    521
# Oct    512
# Apr    502
# Sep    471
# Name: Months_of_the_Yr, dtype: int64
#
# ___________________________________
#        COLUMN:   Contaminant
# ==================================
#
# cr                                       5057
#                                           661
# ga                                        332
# no                                        255
# co                                        180
# gs                                        169
# other:                                     59
# CON                                        25
# re                                         19
# ch                                          3
# other:non                                   3
# NLP                                         2
# crude oil                                   2
# Diesel                                      2
# other: NONE                                 2
# other:WATER FROM OIL PIPELINE               1
# other: nil                                  1
# other: Produce water                        1
# other:Burnt Gas                             1
# other: (fire)                               1
# Asset Damage                                1
# other: Non leaking                          1
# Produce water                               1
# other: Oily Water                           1
# NON LEAKING                                 1
# other: Locally constructed boom             1
# other:Land/Manifold hardstand surface       1
# other: oily wt                              1
# gas                                         1
# NIL                                         1
# other: water leak                           1
# boom                                        1
# other: water-leak                           1
# other                                       1
# Crude                                       1
# other: depresion                            1
# other:NA                                    1
# other:alleged pollution                     1
# co, ga                                      1
# other: gaseous emision                      1
# other:water                                 1
# other:NONE-LEAK                             1
# Name: Contaminant, dtype: int64
#
# ___________________________________
#        COLUMN:   Type_of_fa
# ==================================
#
# pl                      3192
#                         2093
# fl                      1098
# wh                       179
# mf                        37
#                         ...
# other: Delivery line       1
# other:PIPELINE RISER       1
# other:WELL OCATION         1
# other: right of way        1
# gas pipeline               1
# Name: Type_of_fa, Length: 75, dtype: int64
#
# ___________________________________
#        COLUMN:   Cause
# ==================================
#
# sab    6798
# Name: Cause, dtype: int64
#
# ___________________________________
#        COLUMN:   Site_locat
# ==================================
#
# 18" TEBIDABA/BRASS P/L AT IGBEMATORU                                41
# 18'' TEBIDABA/BRASS PIPELINE @ OYEREGBENE                           39
# 18" TEB/BRASS P/L @ IGBEMATORU                                      38
# 10'' CLOUGH CREEK/TEBIDABA PIPELINE AT GBARAUN                      28
# 18'' TEBIDABA/BRASS P/L @ OYEREGBENE                                19
#                                                                     ..
# 24'' Ogoda/Brass Pipeline at Obodhi, Rivers State.                   1
# 28'' BOMU-BONNY TRANS PIPELINE AT OWOKIRI,BONNYLGA,RIVERS STATE.     1
# 14" OKORDIA- RUMUMUEKPE TRUNKLINE @AKARAMINI                         1
# 12" IMO RIVER TL AT OWAZA                                            1
# ABITEYE-UTONANA 16'' PIPELINE.                                       1
# Name: Site_locat, Length: 5530, dtype: int64
#
# ___________________________________
#        COLUMN:   LGA
# ==================================
#
# Southern-Ijaw            992
# Ogba/Egbema/Ndoni        986
# Southern Ijaw            560
# Ahoada-West              302
# Nembe                    258
#                         ...
# Ndokwa West                1
# OGODA/OWUBE/AHODA LGA      1
# OKIRIKA                    1
# umudike                    1
# ASARI-TORU                 1
# Name: LGA, Length: 154, dtype: int64
#
# ___________________________________
#        COLUMN:   States_affected
# ==================================
#
# RI    2985
# BY    2602
# DE     808
# IM     153
# AB     138
# ED     110
# ON       2
# Name: States_affected, dtype: int64
#
# ___________________________________
#        COLUMN:   Spill_area
# ==================================
#
# sw          2986
# la          2914
#              397
# ss           242
# la,ss         87
# iw            60
# la,sw         30
# la,iw         11
# ss,la          9
# of             9
# sw,ss          7
# ss,sw          6
# ns             5
# other          4
# co             4
# sw,iw          3
# sw,la          3
# la,sw,ss       2
# sw,sw          2
# sw,ss,iw       1
# la,ns,ss       1
# la,ns          1
# sw,ns,iw       1
# iw,la,ss       1
# ss,iw,la       1
# ss,ns          1
# co,sw          1
# ss,iw,sw       1
# iw,sw,of       1
# sw,la,ss       1
# ss,la,iw       1
# sw,iw,la       1
# ns,la          1
# sw,la,iw       1
# la,sw,iw       1
# iw,la          1
# Name: Spill_area, dtype: int64
#
# ___________________________________

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6798 entries, 0 to 6797
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                6798 non-null   int64
#  1   Company           6798 non-null   object
#  2   Incident_date     6798 non-null   object
#  3   Days_of_the_Wk    6798 non-null   object
#  4   Months_of_the_Yr  6798 non-null   object
#  5   Years             6798 non-null   int64
#  6   Contaminant       6798 non-null   object
#  7   Type_of_fa        6798 non-null   object
#  8   Cause             6798 non-null   object
#  9   Site_locat        6798 non-null   object
#  10  Latitude          6798 non-null   float64
#  11  Longitude         6798 non-null   float64
#  12  LGA               6798 non-null   object
#  13  States_affected   6798 non-null   object
#  14  Spill_area        6798 non-null   object
#  15  MoY               6798 non-null   int64
#  16  DoW               6798 non-null   int64
# dtypes: float64(2), int64(4), object(11)
# memory usage: 903.0+ KB

# %%
data['Incident_date'] = pd.to_datetime(data['Incident_date'], errors='coerce')

# %%
data.drop(['Days_of_the_Wk', 'Months_of_the_Yr'], axis=1 , inplace=True)

# %%
data['year'] = data['Incident_date'].dt.year
data['month'] = data['Incident_date'].dt.month
data['dayofweek'] = data['Incident_date'].dt.dayofweek
data['weekofyear'] = data['Incident_date'].dt.week
data['year_quater'] = data['Incident_date'].dt.quarter
data['day'] = data['Incident_date'].dt.day
data['hour'] = data['Incident_date'].dt.hour
# Out:
# <ipython-input-28-cd38a31b82df>:4: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.
#   data['weekofyear'] = data['Incident_date'].dt.week

# %%
data.head()
# Out:
#    ID Company Incident_date Contaminant Type_of_fa Cause  \
# 0   1    SPDC    2010-01-03          cr              sab
# 1   2    SPDC    2010-01-03          cr              sab
# 2   3    NAOC    2010-01-05          cr              sab
# 3   4    SPDC    2010-01-05          cr              sab
# 4   5    NAOC    2010-01-06          cr              sab
#
#                                         Site_locat  Latitude  Longitude  \
# 0                      12" IMR-EBUBU T/L AT KOMKOM  4.878083   7.172556
# 1                        8" ISIMIRI D/L AT ISIMIRI  4.878194   7.230583
# 2                         24" OGODA/BRASS P/L ODAU  4.833556   6.498889
# 3                                       Kokori d\L  5.597444   6.068583
# 4  18" TEBIDABA/BRASS P/L AT OGONIGBENE 1 M8 RISER  4.474889   6.127833
#
#              LGA States_affected Spill_area  year  month  dayofweek  \
# 0         Oyigbo              RI         la  2010      1          6
# 1      Ukwa West              AB         sw  2010      1          6
# 2     Abua-Odual              RI         la  2010      1          1
# 3  Ughelli-North              DE         la  2010      1          1
# 4          Brass              BY         sw  2010      1          2
#
#    weekofyear  year_quater  day  hour
# 0          53            1    3     0
# 1          53            1    3     0
# 2           1            1    5     0
# 3           1            1    5     0
# 4           1            1    6     0

# %%
data.drop(['Years', 'MoY', 'DoW'], axis=1, inplace=True)

# %%
data.describe()
# Out:
#                 ID       Latitude      Longitude
# count  6798.000000    6798.000000    6798.000000
# mean   3399.500000      33.125266     150.496819
# std    1962.557897    1704.260482    8410.202017
# min       1.000000       0.000000       0.000000
# 25%    1700.250000       4.567806       6.007806
# 50%    3399.500000       4.944778       6.456194
# 75%    5098.750000       5.405222       6.689826
# max    6798.000000  122735.126000  511781.050000

# %% [markdown]
# Target variable

# %%
data['LGA'].unique()
# Out:
# array(['Oyigbo', 'Ukwa West', 'Abua-Odual', 'Ughelli-North', 'Brass',
#        'Emuoha', 'Ohaji/Egbema', 'Gokana', 'Southern Ijaw',
#        'Warri-South-West', 'Isoko-North', 'Ikwerre', 'Burutu', 'Etche',
#        'Ogba/Egbema/Ndoni', 'Degema', 'Nembe', 'Ahoada West',
#        'Ahoada-West', ' ', 'Bonny', 'Ndokwa-East', 'Obio/Akpor',
#        'Asari-Toru', 'Ogbia', 'Akuku Toru', 'Isoko-South', 'Ekeremor',
#        'Oguta', 'Ahoada East', 'AHOADA WEST', 'Yenagoa', 'Abua/Odual',
#        'Bomadi', 'Akuku-Toru', 'Warri-North', 'Isoko South', 'Omumma',
#        'Akoko-Edo', 'Ethiope West', 'Ikwere', 'DEGEMA', 'GOKANA',
#        'Warri-South', 'Ndokwa East', 'Sapele', 'EMOHUA', 'Etsako-East',
#        'Oru West', 'OGBA/EGBEMA/NDONI', 'ETCHE, EBERI/OMUMMA',
#        'AKUKU-TORU', 'UKWA WEST', 'Okpe', 'Ukwa-West', 'IKWERE',
#        'SOUTHERN IJAW', 'BRASS NEMBE', 'Uvwie', 'Ohionmwon', 'Ika-South',
#        'Eleme', 'OYIGBO', 'Ughelli South', 'Ikpoba-Okha', 'OHAJI/EGBEMA',
#        'ABUA/ODUA', 'Etsako-West', 'Ethiope-West', 'Udu', 'TAI', 'Tai',
#        'IKWERRE', 'GIO', 'EGBEDA', 'Ughelli-South', 'Etsako West',
#        'Etsako East', 'Esan-West', 'ASARI-TORU', 'ELEME', 'UKWA EAST',
#        'Ughelli North', 'OBIO/AKPOR', 'Port-Harcourt', 'BONNY', 'ILAJE',
#        'Ndokwa West', 'Ndokwa-West', 'Warri South-West', 'Ahoada-East',
#        'Southern-Ijaw', 'ONELGA', 'SILGA', 'Southern ijaw', 'Silga',
#        'Uhunmwonde', 'GOHANA', 'ANDONI', 'Andoni', 'Oredo', 'NEMBE',
#        'NELGA', 'Ethiope-East', 'UHUNDE', 'Nelga', 'Osisioma', 'onelga',
#        'ah', 'Okrika', 'silga', 'umudike', 'Umudike', 'WALGA', 'EKEREMO',
#        'Onelga', 'EMOHUA/AHOADA-EAST', 'OBIGBO', 'ELEN-KALABARI',
#        'WARRI SOUTH', 'bayelsa', 'Adoni', 'AWELGA', 'AHODA WEST', 'OGBIA',
#        'EKEREMOR', 'Ukwuani', 'AH0DA', 'AHODA', 'ahouda west',
#        'Ahoda West', 'Emouha', 'Tai/Eleme', 'ABOUA', 'Ogo-Bolo',
#        'warri north', 'One', 'Sagbama', 'AUA/ODUAL', 'OKIRIKA',
#        'Ukwa- west', 'OELGA', 'IKWERRE LGA', 'ijaye', 'ONE', 'igiriukwu',
#        'OGODA/OWUBE/AHODA LGA', 'Awelga Rivers state', 'Ahoada west',
#        'Kolokuma/Opokuma', 'Esan-South-East', 'YENAGOA',
#        'ONELGA / RIVERS', 'Ukwa-East'], dtype=object)

# %%
import folium

# %%
data.head()
# Out:
#    ID Company Incident_date Days_of_the_Wk Months_of_the_Yr Contaminant  \
# 0   1    SPDC    2010-01-03            Sun              Jan          cr
# 1   2    SPDC    2010-01-03            Sun              Jan          cr
# 2   3    NAOC    2010-01-05            Tue              Jan          cr
# 3   4    SPDC    2010-01-05            Tue              Jan          cr
# 4   5    NAOC    2010-01-06            Wed              Jan          cr
#
#   Type_of_fa Cause                                       Site_locat  Latitude  \
# 0              sab                      12" IMR-EBUBU T/L AT KOMKOM  4.878083
# 1              sab                        8" ISIMIRI D/L AT ISIMIRI  4.878194
# 2              sab                         24" OGODA/BRASS P/L ODAU  4.833556
# 3              sab                                       Kokori d\L  5.597444
# 4              sab  18" TEBIDABA/BRASS P/L AT OGONIGBENE 1 M8 RISER  4.474889
#
#    Longitude            LGA States_affected Spill_area
# 0   7.172556         Oyigbo              RI         la
# 1   7.230583      Ukwa West              AB         sw
# 2   6.498889     Abua-Odual              RI         la
# 3   6.068583  Ughelli-North              DE         la
# 4   6.127833          Brass              BY         sw

# %%
lga_map = folium.Map(location=[4.878083 ,7.172556])

# folium.Marker([4.878194, 7.230583], popup="LGA").add_to(lga_map)

# folium.Circle([4.833556, 6.498889], radius=1000, color="red", fill=True,ffil_color="red").add_to(lga_map)

lga = list(data['LGA'].unique())
mapped_lga = []

for i in range(data.shape[0]):
    if data.loc[i, 'LGA'] not in mapped_lga:
        lon = data.loc[i,'Longitude']
        lat = data.loc[i,'Latitude']
        # folium.Marker(location=(lat, lon)).add_to(m)
        folium.Circle(location=(lat, lon), radius=100, color="red", fill=True, ffil_color="red").add_to(lga_map)

        mapped_lga.append(data.loc[i, 'LGA'])

lga_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_5859ceafe23a46db84d82ff1ad9fa1f7%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_5859ceafe23a46db84d82ff1ad9fa1f7%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_5859ceafe23a46db84d82ff1ad9fa1f7%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_5859ceafe23a46db84d82ff1ad9fa1f7%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B4.878083%2C%207.172556%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20 ...

# %% [markdown]
# Checking to group lga based on spill_area and see how many states are involved

# %%
data.columns
# Out:
# Index(['ID', 'Company', 'Incident_date', 'Contaminant', 'Type_of_fa', 'Cause',
#        'Site_locat', 'Latitude', 'Longitude', 'LGA', 'States_affected',
#        'Spill_area', 'year', 'month', 'dayofweek', 'weekofyear', 'year_quater',
#        'day', 'hour'],
#       dtype='object')

# %%
data['Spill_area'].value_counts()
# Out:
# sw          2986
# la          2914
#              397
# ss           242
# la,ss         87
# iw            60
# la,sw         30
# la,iw         11
# ss,la          9
# of             9
# sw,ss          7
# ss,sw          6
# ns             5
# other          4
# co             4
# sw,iw          3
# sw,la          3
# la,sw,ss       2
# sw,sw          2
# sw,ss,iw       1
# la,ns,ss       1
# la,ns          1
# sw,ns,iw       1
# iw,la,ss       1
# ss,iw,la       1
# ss,ns          1
# co,sw          1
# ss,iw,sw       1
# iw,sw,of       1
# sw,la,ss       1
# ss,la,iw       1
# sw,iw,la       1
# ns,la          1
# sw,la,iw       1
# la,sw,iw       1
# iw,la          1
# Name: Spill_area, dtype: int64

# %%
plt.figure(figsize=(20, 9))
sns.set_style('whitegrid')
sns.set_color_codes(palette="deep")
plt.xticks(rotation=90)

sns.countplot(data=data, x='Spill_area')
# Out:
# <AxesSubplot:xlabel='Spill_area', ylabel='count'>

# %%
temp = pd.DataFrame(data.groupby('Spill_area')['Longitude', 'Latitude'].mean())
temp
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-71-cba980fbebce> in <module>
# ----> 1 tem = pd.DataFrame(data.groupby('Spill_area')['Longitude', 'Latitude'].mean())
#       2 tem
#
# AttributeError: 'int' object has no attribute 'groupby'

# %%
data.groupby('Spill_area')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-73-6cc99f097fac> in <module>
# ----> 1 data.groupby('Spill_area')
#
# AttributeError: 'int' object has no attribute 'groupby'

# %%
data.info()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-74-6208d269f320> in <module>
# ----> 1 data.info()
#
# AttributeError: 'int' object has no attribute 'info'

# %%
sam = folium.Map(location=[6.853860, 4.707157])

for i in range(temp.shape[0]):
    # print(f"{i}    :   {temp.iloc[i]['Longitude']} ")
    long = temp.iloc[i]['Longitude']

    lat = temp.iloc[i]['Latitude']

    

    folium.Circle(location=(lat, long),  radius, fill=True, color='red', ffill_color='red')
# Out:
# 0    :   2474.4497220539047
# 1    :   6.853860275
# 2    :   6.4711944
# 3    :   6.347283498333334
# 4    :   7.2543055999999995
# 5    :   6.4245
# 6    :   6.636715
# 7    :   6.6345545238675285
# 8    :   6.604235536363635
# 9    :   6.561611099999999
# 10    :   6.6155833
# 11    :   6.568259385057471
# 12    :   6.310180709999999
# 13    :   6.0591833
# 14    :   6.16690835
# 15    :   6.40517222
# 16    :   6.7958300000000005
# 17    :   5.947012966666667
# 18    :   6.011363375
# 19    :   6.339269078884299
# 20    :   6.6304444
# 21    :   7.068444400000001
# 22    :   6.542916133333333
# 23    :   6.50026
# 24    :   7.0278056
# 25    :   6.351430733333333
# 26    :   6.091291610582721
# 27    :   6.066870366666667
# 28    :   6.3977778
# 29    :   6.485489833333333
# 30    :   6.0201944
# 31    :   5.5197222
# 32    :   7.22325
# 33    :   5.930515085714285
# 34    :   7.0208881
# 35    :   6.54043055
